# %%
import requests
import telebot
import time
import datetime
from multiprocessing import *
import schedule
import numpy as np
from random import randint
import pandas as pd
import psycopg2
from pandas.plotting import table 
import seaborn as sns
import matplotlib.pyplot as plt
from telebot.types import InputMediaPhoto
from datetime import timedelta
import xlsxwriter
import pandas.util.testing as tm
from pandas.testing import assert_frame_equal
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import re
from datetime import date
import sys
import os
sys.path.insert(0, os.path.expanduser('./scripts'))
from For_metrics import report
from CPO import report_CPO, cur_id

# chat_id='-1001747077372'
channel_id = '-1001742418776'

def conn():    

    gp_conn = psycopg2.connect(host='gpdb-pgbouncer.taxi.yandex.net',
                           port=5432,
                           database='ritchie',
                           user='xshoker',
                           password=open(os.path.expanduser('~/bot/Программы/password.txt')).read())
    return gp_conn

    
def start_process(): #Запуск Process
    p1 = Process(target=P_schedule.start_schedule, args=()).start()
    keyboard1 = telebot.types.ReplyKeyboardMarkup(True, True)
            
    bot.polling()



class P_schedule():
    
    def start_schedule(): #Запуск schedule
        ######Параметры для schedule######
        try:
            if datetime.datetime.today().weekday() > 0:
                schedule.every().day.at("14:10").do(P_schedule.send_message)
                schedule.every().day.at("16:00").do(P_schedule.send_message_week)
            else:
                pass
            schedule.every().day.at("16:10").do(P_schedule.CPO_day)
        except:
            pass
        ##################################
        
        while True: #Запуск цикла
            schedule.run_pending()
            time.sleep(1)
            
    def CPO_day():
        CPO = report_CPO()
        return CPO
    
    def cur():
        cur = cur_id()
        return cur
 
    ####Функции для выполнения заданий по времени  
    def send_message():
        report()
#         bot.send_photo(chat_id = chat_id, photo=open(os.path.expanduser('~/bot/Msc.png'), 'rb'))
#         bot.send_photo(chat_id = chat_id, photo=open(os.path.expanduser('~/bot/Spb.png'), 'rb'))
#         bot.send_photo(chat_id = chat_id, photo=open(os.path.expanduser('~/bot/Nnv.png'), 'rb'))
#         bot.send_photo(chat_id = chat_id, photo=open(os.path.expanduser('~/bot/Kzn.png'), 'rb'))
#         bot.send_photo(chat_id = chat_id, photo=open(os.path.expanduser('~/bot/Ekb.png'), 'rb'))
#         bot.send_photo(chat_id = chat_id, photo=open(os.path.expanduser('~/bot/Krd.png'), 'rb'))
#         bot.send_photo(chat_id = chat_id, photo=open(os.path.expanduser('~/bot/Rnd.png'), 'rb'))
#         bot.send_photo(chat_id = chat_id, photo=open(os.path.expanduser('~/bot/Nsk.png'), 'rb'))
#         bot.send_photo(chat_id = chat_id, photo=open(os.path.expanduser('~/bot/Irk.png'), 'rb'))
        bot.send_photo(chat_id = channel_id, photo=open(os.path.expanduser('~/bot/Msc.png'), 'rb'))
        bot.send_photo(chat_id = channel_id, photo=open(os.path.expanduser('~/bot/Spb.png'), 'rb'))
        bot.send_photo(chat_id = channel_id, photo=open(os.path.expanduser('~/bot/Nnv.png'), 'rb'))
        bot.send_photo(chat_id = channel_id, photo=open(os.path.expanduser('~/bot/Kzn.png'), 'rb'))
        bot.send_photo(chat_id = channel_id, photo=open(os.path.expanduser('~/bot/Ekb.png'), 'rb'))
        bot.send_photo(chat_id = channel_id, photo=open(os.path.expanduser('~/bot/Krd.png'), 'rb'))
        bot.send_photo(chat_id = channel_id, photo=open(os.path.expanduser('~/bot/Rnd.png'), 'rb'))
        bot.send_photo(chat_id = channel_id, photo=open(os.path.expanduser('~/bot/Nsk.png'), 'rb'))
#         bot.send_photo(chat_id = channel_id, photo=open(os.path.expanduser('~/bot/Irk.png'), 'rb'))
    ################
    
    def send_message_week():
        report()
#         bot.send_photo(chat_id = chat_id, photo=open(os.path.expanduser('~/bot/Msc_week.png'), 'rb'))
#         bot.send_photo(chat_id = chat_id, photo=open(os.path.expanduser('~/bot/Spb_week.png'), 'rb'))
#         bot.send_photo(chat_id = chat_id, photo=open(os.path.expanduser('~/bot/Nnv_week.png'), 'rb'))
#         bot.send_photo(chat_id = chat_id, photo=open(os.path.expanduser('~/bot/Kzn_week.png'), 'rb'))
#         bot.send_photo(chat_id = chat_id, photo=open(os.path.expanduser('~/bot/Ekb_week.png'), 'rb'))
#         bot.send_photo(chat_id = chat_id, photo=open(os.path.expanduser('~/bot/Krd_week.png'), 'rb'))
#         bot.send_photo(chat_id = chat_id, photo=open(os.path.expanduser('~/bot/Rnd_week.png'), 'rb'))
#         bot.send_photo(chat_id = chat_id, photo=open(os.path.expanduser('~/bot/Nsk_week.png'), 'rb'))
#         bot.send_photo(chat_id = chat_id, photo=open(os.path.expanduser('~/bot/Irk_week.png'), 'rb'))
        bot.send_photo(chat_id = channel_id, photo=open(os.path.expanduser('~/bot/Msc_week.png'), 'rb'))
        bot.send_photo(chat_id = channel_id, photo=open(os.path.expanduser('~/bot/Spb_week.png'), 'rb'))
        bot.send_photo(chat_id = channel_id, photo=open(os.path.expanduser('~/bot/Nnv_week.png'), 'rb'))
        bot.send_photo(chat_id = channel_id, photo=open(os.path.expanduser('~/bot/Kzn_week.png'), 'rb'))
        bot.send_photo(chat_id = channel_id, photo=open(os.path.expanduser('~/bot/Ekb_week.png'), 'rb'))
        bot.send_photo(chat_id = channel_id, photo=open(os.path.expanduser('~/bot/Krd_week.png'), 'rb'))
        bot.send_photo(chat_id = channel_id, photo=open(os.path.expanduser('~/bot/Rnd_week.png'), 'rb'))
        bot.send_photo(chat_id = channel_id, photo=open(os.path.expanduser('~/bot/Nsk_week.png'), 'rb'))
#         bot.send_photo(chat_id = channel_id, photo=open(os.path.expanduser('~/bot/Irk_week.png'), 'rb'))
#     ################

    
            
if __name__ == "__main__":
    sys.path.insert(0, os.path.expanduser("./scripts"))
    API_TOKEN = open(os.path.expanduser('~/bot/Программы/Token_Api_bot.txt')).read()
    bot = telebot.TeleBot(API_TOKEN)
    start_process()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.
